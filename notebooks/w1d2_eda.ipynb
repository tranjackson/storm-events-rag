# %%
import pandas as pd, glob
df = pd.read_csv(sorted(glob.glob("../data/raw/*d2020*.csv.gz"))[0])
df[["DAMAGE_PROPERTY", "DAMAGE_CROPS", "BEGIN_DATE_TIME", "EVENT_TYPE"]].sample(10)
# Out:
#       DAMAGE_PROPERTY DAMAGE_CROPS     BEGIN_DATE_TIME  \
# 6029            0.00K        0.00K  03-MAR-20 11:05:00
# 6218            0.00K        0.00K  01-MAR-20 08:00:00
# 45196           0.00K        0.00K  15-NOV-20 12:01:00
# 15958           0.00K        0.00K  09-APR-20 13:39:00
# 28923             NaN          NaN  03-MAY-20 16:21:00
# 27977           0.00K        0.00K  30-JUL-20 17:42:00
# 30426          20.00K        0.00K  22-JUL-20 14:20:00
# 31800           0.00K        0.00K  31-JUL-20 00:25:00
# 911             0.00K        0.00K  13-MAR-20 14:00:00
# 26832           0.20K        0.00K  03-MAY-20 15:57:00
#
#                      EVENT_TYPE
# 6029                  High Wind
# 6218                  High Wind
# 45196  Marine Thunderstorm Wind
# 15958         Thunderstorm Wind
# 28923         Thunderstorm Wind
# 27977               Flash Flood
# 30426         Thunderstorm Wind
# 31800  Marine Thunderstorm Wind
# 911                  Heavy Rain
# ...
